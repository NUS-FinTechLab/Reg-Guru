# %% [markdown]
# # SPARQL Query

# %%
sparql = SPARQLWrapper("https://publications.europa.eu/webapi/rdf/sparql")
sparql.setReturnFormat(JSON)

# %%
query = """
PREFIX cdm: <http://publications.europa.eu/ontology/cdm#>
PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
PREFIX dc: <http://purl.org/dc/elements/1.1/>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX owl: <http://www.w3.org/2002/07/owl#>

SELECT 
  DISTINCT (GROUP_CONCAT(DISTINCT STR(?work); SEPARATOR=",") AS ?cellarURIs)
  (GROUP_CONCAT(DISTINCT STR(?title_); SEPARATOR=",") AS ?title)
  # ?langIdentifier
  (GROUP_CONCAT(DISTINCT STR(?mtype); SEPARATOR=",") AS ?mtypes)
  (GROUP_CONCAT(DISTINCT STR(?thumbnail); SEPARATOR=",") AS ?thumbnails)
  (GROUP_CONCAT(DISTINCT STR(?resType); SEPARATOR=",") AS ?workTypes)
  (GROUP_CONCAT(DISTINCT STR(?agentName); SEPARATOR=",") AS ?authors)
  (GROUP_CONCAT(DISTINCT STR(?privateAgentName); SEPARATOR=";") AS ?privateAuthors)
  # ?date
  (GROUP_CONCAT(DISTINCT STR(?subjectLabel); SEPARATOR=",") AS ?subjects)
  (GROUP_CONCAT(DISTINCT STR(?workId_); SEPARATOR=",") AS ?workIds)
WHERE {
  GRAPH ?gw {
    # ?work rdf:type ?resType ;
          cdm:work_date_document ?date ;
          cdm:work_id_document ?workId_ ;
          cdm:work_is_about_concept_eurovoc ?subject .
    FILTER(?resType = cdm:resource_legal)
    FILTER(xsd:date(?date) < "2023-01-01"^^xsd:date)
    
    GRAPH ?gs {
      # ?subject skos:prefLabel ?subjectLabel .
      FILTER(LANG(?subjectLabel) = "en")
    }
  }

  GRAPH ?eg {
    # ?exp cdm:expression_belongs_to_work ?work ;
         cdm:expression_title ?title_ ;
         cdm:expression_uses_language ?lg .
    FILTER(LANG(?title_) = "en" || LANG(?title_) = "eng" || LANG(?title_) = "")

    GRAPH ?lgc {
      # ?lg dc:identifier ?langIdentifier .
      FILTER(STR(?langIdentifier) = "ENG")
    }
  }

  GRAPH ?gm {
    # ?manif cdm:manifestation_manifests_expression ?exp ;
           cdm:manifestation_type ?mtype .
    OPTIONAL { ?manif cdm:manifestation_has_thumbnail ?thumbnail }
  }

  OPTIONAL {
    GRAPH ?gagent {
      {
        # ?work cdm:work_contributed_to_by_agent ?agent .
      } UNION {
        # ?work cdm:work_created_by_agent ?agent .
      } UNION {
        # ?work cdm:work_authored_by_agent ?agent .
      }
    }
    GRAPH ?ga {
      # ?agent skos:prefLabel ?agentName .
      FILTER(LANG(?agentName) = "en")
    }
  }

  OPTIONAL {
    GRAPH ?persAuthor {
      {
        # ?work cdm:work_contributed_to_by_agent ?privateAgent .
      } UNION {
        # ?work cdm:work_authored_by_agent ?privateAgent .
      }
      # ?privateAgent rdf:type cdm:person ;
                    cdm:agent_name ?privateAgentName .
    }
  }
}
GROUP BY ?work ?date ?langIdentifier
ORDER BY DESC(?date)
LIMIT 100
"""

# %%
query = """
prefix cdm: <http://publications.europa.eu/ontology/cdm#>
prefix purl: <http://purl.org/dc/elements/1.1/>
select distinct ?item ?date ?class
where {
    # ?work cdm:date_creation_legacy ?date.
    # ?w a ?class .
    # ?expr cdm:expression_belongs_to_work ?work ;
        cdm:expression_uses_language ?lang .
    # ?lang purl:identifier ?langCode .
    # ?manif cdm:manifestation_manifests_expression ?expr;
        cdm:manifestation_type "pdfa1a".
    # ?item cdm:item_belongs_to_manifestation ?manif.
    FILTER (
        # ?date > "2016-05-23T10:20:13+05:30"^^xsd:dateTime
        AND
        # ?date < "2020-05-23T10:20:13+05:30"^^xsd:dateTime
    ).
    FILTER(
        # ?class in (
        <http://publications.europa.eu/ontology/cdm#document_cjeu>,
        <http://publications.europa.eu/ontology/cdm#case-law>,
        <http://publications.europa.eu/ontology/cdm#summary_caselaw>,
        <http://publications.europa.eu/ontology/cdm#summary_caselaw_jure>
        )
    )
    FILTER(STR(?langCode) = "ENG")
}
LIMIT 10
"""

# %%
### Select format? = html or xhtml


query = """
prefix cdm: <http://publications.europa.eu/ontology/cdm#>
prefix purl: <http://purl.org/dc/elements/1.1/>
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>

select distinct ?item ?expr_title ?celex ?date ?class ?className ?authorName #  ?subject
where {
    # ?work cdm:work_date_document ?date ;
        rdf:type cdm:resource_legal .
    # ?w a ?class .
    # ?class rdfs:subClassOf cdm:resource_legal .
    # ?expr cdm:expression_belongs_to_work ?work ;
        cdm:expression_title ?expr_title ;
        cdm:expression_uses_language ?lang .
    # ?lang purl:identifier ?langCode .
    # ?manif cdm:manifestation_manifests_expression ?expr;
        # cdm:manifestation_type "pdfa1a".
        cdm:manifestation_type "xhtml".
    # ?item cdm:item_belongs_to_manifestation ?manif.
    
    FILTER (
        # ?date > "2000-01-01T23:59:59+08:00"^^xsd:dateTime
        AND
        # ?date < "2025-08-01T23:59:59+08:00"^^xsd:dateTime
    ).

    FILTER(STR(?langCode) = "ENG")

    OPTIONAL { ?work cdm:work_id_celex ?celex . }
    
    BIND(
        IF(CONTAINS(STR(?class), "#"),
            STRAFTER(STR(?class), "#"),
            STRAFTER(STR(?class), "/")
        ) AS ?className
    )
    
    OPTIONAL {
        GRAPH ?gagent {
            {
            # ?work cdm:work_contributed_to_by_agent ?author .
            } UNION {
            # ?work cdm:work_created_by_agent ?author .
            } UNION {
            # ?work cdm:work_authored_by_agent ?author .
            }
        }
    
        
    OPTIONAL {
        GRAPH ?glabel {
        # ?author skos:prefLabel ?authorName .
        FILTER(LANG(?authorName) = "en")
        }
    }
    }

}
ORDER BY ?date
"""

# %%
from rdflib import Namespace
Namespace("http://publications.europa.eu/ontology/cdm#")
# Out:
# Namespace('http://publications.europa.eu/ontology/cdm#')

# %%
sparql.setQuery(query)
results = sparql.query().convert()
results["results"]["bindings"]
# Out:
# [{'item': {'type': 'uri',
#    'value': 'http://publications.europa.eu/resource/cellar/ea3bdcba-e537-4749-b2dc-4457734dbfcf.0002.02/DOC_1'},
#   'expr_title': {'type': 'literal',
#    'value': 'Opinion of Advocate General Sharpston delivered on 13 March 2008. # Ecotrade SpA v Agenzia delle Entrate - Ufficio di Genova 3. # Reference for a preliminary ruling: Commissione tributaria provinciale di Genova - Italy. # Sixth VAT Directive - Reverse charge procedure - Right to deduct - Time-bar - Irregularity in accounts and tax returns affecting transactions subject to the reverse charge procedure. # Joined cases C-95/07 and C-96/07.'},
#   'date': {'type': 'typed-literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#date',
#    'value': '2008-03-13'},
#   'class': {'type': 'uri',
#    'value': 'http://publications.europa.eu/ontology/cdm#act_consolidated'},
#   'className': {'type': 'literal', 'value': 'act_consolidated'},
#   'authorName': {'type': 'literal',
#    'xml:lang': 'en',
#    'value': 'Court of Justice'}},
#  {'item': {'type': 'uri',
#    'value': 'http://publications.europa.eu/resource/cellar/ea3bdcba-e537-4749-b2dc-4457734dbfcf.0002.02/DOC_1'},
#   'expr_title': {'type': 'literal',
#    'value': 'Opinion of Advocate General Sharpston delivered on 13 March 2008. # Ecotrade SpA v Agenzia delle Entrate - Ufficio di Genova 3. # Reference for a preliminary ruling: Commissione tributaria provinciale di Genova - Italy. # Sixth VAT Directive - Reverse charge procedure - Right to deduct - Time-bar - Irregularity in accounts and tax returns affecting transactions subject to the reverse charge procedure. # Joined cases C-95/07 and C-96/07.'},
#   'date': {'type': 'typed-literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#date',
#    'value': '2008-03-13'},
#   'class': {'type': 'uri',
#    'value': 'http://publications.europa.eu/ontology/cdm#act_preparatory'},
#   'className': {'type': 'literal', 'value': 'act_preparatory'},
#   'authorName': {'type': 'literal',
#    'xml:lang': 'en',
#    'value': 'Court of Justice'}},
#  {'item': {'type': 'uri',
#    'value': 'http://publications.europa.eu/resource/cellar/ea3bdcba-e537-4749-b2dc-4457734dbfcf.0002.02/DOC_1'},
#   'expr_title': {'type': 'literal',
#    'value': 'Opinion of Advocate General Sharpston delivered on 13 March 2008. # Ecotrade SpA v Agenzia delle Entrate - Ufficio di Genova 3. # Reference for a preliminary ruling: Commissione tributaria provinciale di Genova - Italy. # Sixth VAT Directive - Reverse charge procedure - Right to deduct - Time-bar - Irregularity in accounts and tax returns affecting transactions subject to the reverse charge procedure. # Joined cases C-95/07 and C-96/07.'},
#   'date': {'type': 'typed-literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#date',
#    'value': '2008-03-13'},
#   'class': {'type': 'uri',
#    'value': 'http://publications.europa.eu/ontology/cdm#agreement_international'},
#   'className': {'type': 'literal', 'value': 'agreement_international'},
#   'authorName': {'type': 'literal',
#    'xml:lang': 'en',
#    'value': 'Court of Justice'}},
#  {'item': {'type': 'uri',
#    'value': 'http://publications.europa.eu/resource/cellar/ea3bdcba-e537-4749-b2dc-4457734dbfcf.0002.02/DOC_1'},
#   'expr_title': {'type': 'literal',
#    'value': 'Opinion of Advocate General Sharpston delivered on 13 March 2008. # Ecotrade SpA v Agenzia delle Entrate - Ufficio di Genova 3. # Reference for a preliminary ruling: Commissione tributaria provinciale di Genova - Italy. # Sixth VAT Directive - Reverse charge procedure - Right to deduct - Time-bar - Irregularity in accounts and tax returns affecting transactions subject to the reverse charge procedure. # Joined cases C-95/07 and C-96/07.'},
#   'date': {'type': 'typed-literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#date',
#    'value': '2008-03-13'},
#   'class': {'type': 'uri',
#    'value': 'http://publications.europa.eu/ontology/cdm#case-law'},
#   'className': {'type': 'literal', 'value': 'case-law'},
#   'authorName': {'type': 'literal',
#    'xml:lang': 'en',
#    'value': 'Court of Justice'}},
#  {'item': {'type': 'uri',
#    'value': 'http://publications.europa.eu/resource/cellar/ea3bdcba-e537-4749-b2dc-4457734dbfcf.0002.02/DOC_1'},
#   'expr_title': {'type': 'literal',
#    'value': 'Opinion of Advocate General Sharpston delivered on 13 March 2008. # Ecotrade SpA v Agenzia delle Entrate - Ufficio di Genova 3. # Reference for a preliminary ruling: Commissione tributaria provinciale di Genova - Italy. # Sixth VAT Directive - Reverse charge procedure - Right to deduct - Time-bar - Irregularity in accounts and tax returns affecting transactions subject to the reverse charge procedure. # Joined cases C-95/07 and C-96/07.'},
#   'date': {'type': 'typed-literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#date',
#    'value': '2008-03-13'},
#   'class': {'type': 'uri',
#    'value': 'http://publications.europa.eu/ontology/cdm#document_cjeu'},
#   'className': {'type': 'literal', 'value': 'document_cjeu'},
#   'authorName': {'type': 'literal',
#    'xml:lang': 'en',
#    'value': 'Court of Justice'}},
#  {'item': {'type': 'uri',
#    'value': 'http://publications.europa.eu/resource/cellar/ea3bdcba-e537-4749-b2dc-4457734dbfcf.0002.02/DOC_1'},
#   'expr_title': {'type': 'literal',
#    'value': 'Opinion of Advocate General Sharpston delivered on 13 March 2008. # Ecotrade SpA v Agenzia delle Entrate - Ufficio di Genova 3. # Reference for a preliminary ruling: Commissione tributaria provinciale di Genova - Italy. # Sixth VAT Directive - Reverse charge procedure - Right to deduct - Time-bar - Irregularity in accounts and tax returns affecting transactions subject to the reverse charge procedure. # Joined cases C-95/07 and C-96/07.'},
#   'date': {'type': 'typed-literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#date',
#    'value': '2008-03-13'},
#   'class': {'type': 'uri',
#    'value': 'http://publications.europa.eu/ontology/cdm#document_efta'},
#   'className': {'type': 'literal', 'value': 'document_efta'},
#   'authorName': {'type': 'literal',
#    'xml:lang': 'en',
#    'value': 'Court of Justice'}},
#  {'item': {'type': 'uri',
#    'value': 'http://publications.europa.eu/resource/cellar/ea3bdcba-e537-4749-b2dc-4457734dbfcf.0002.02/DOC_1'},
#   'expr_title': {'type': 'literal',
#    'value': 'Opinion of Advocate General Sharpston delivered on 13 March 2008. # Ecotrade SpA v Agenzia delle Entrate - Ufficio di Genova 3. # Reference for a preliminary ruling: Commissione tributaria provinciale di Genova - Italy. # Sixth VAT Directive - Reverse charge procedure - Right to deduct - Time-bar - Irregularity in accounts and tax returns affecting transactions subject to the reverse charge procedure. # Joined cases C-95/07 and C-96/07.'},
#   'date': {'type': 'typed-literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#date',
#    'value': '2008-03-13'},
#   'class': {'type': 'uri',
#    'value': 'http://publications.europa.eu/ontology/cdm#fragment_resource_legal'},
#   'className': {'type': 'literal', 'value': 'fragment_resource_legal'},
#   'authorName': {'type': 'literal',
#    'xml:lang': 'en',
#    'value': 'Court of Justice'}},
#  {'item': {'type': 'uri',
#    'value': 'http://publications.europa.eu/resource/cellar/ea3bdcba-e537-4749-b2dc-4457734dbfcf.0002.02/DOC_1'},
#   'expr_title': {'type': 'literal',
#    'value': 'Opinion of Advocate General Sharpston delivered on 13 March 2008. # Ecotrade SpA v Agenzia delle Entrate - Ufficio di Genova 3. # Reference for a preliminary ruling: Commissione tributaria provinciale di Genova - Italy. # Sixth VAT Directive - Reverse charge procedure - Right to deduct - Time-bar - Irregularity in accounts and tax returns affecting transactions subject to the reverse charge procedure. # Joined cases C-95/07 and C-96/07.'},
#   'date': {'type': 'typed-literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#date',
#    'value': '2008-03-13'},
#   'class': {'type': 'uri',
#    'value': 'http://publications.europa.eu/ontology/cdm#legislation_complementary'},
#   'className': {'type': 'literal', 'value': 'legislation_complementary'},
#   'authorName': {'type': 'literal',
#    'xml:lang': 'en',
#    'value': 'Court of Justice'}},
#  {'item': {'type': 'uri',
#    'value': 'http://publications.europa.eu/resource/cellar/ea3bdcba-e537-4749-b2dc-4457734dbfcf.0002.02/DOC_1'},
#   'expr_title': {'type': 'literal',
#    'value': 'Opinion of Advocate General Sharpston delivered on 13 March 2008. # Ecotrade SpA v Agenzia delle Entrate - Ufficio di Genova 3. # Reference for a preliminary ruling: Commissione tributaria provinciale di Genova - Italy. # Sixth VAT Directive - Reverse charge procedure - Right to deduct - Time-bar - Irregularity in accounts and tax returns affecting transactions subject to the reverse charge procedure. # Joined cases C-95/07 and C-96/07.'},
#   'date': {'type': 'typed-literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#date',
#    'value': '2008-03-13'},
#   'class': {'type': 'uri',
#    'value': 'http://publications.europa.eu/ontology/cdm#legislation_secondary'},
#   'className': {'type': 'literal', 'value': 'legislation_secondary'},
#   'authorName': {'type': 'literal',
#    'xml:lang': 'en',
#    'value': 'Court of Justice'}},
#  {'item': {'type': 'uri',
#    'value': 'http://publications.europa.eu/resource/cellar/ea3bdcba-e537-4749-b2dc-4457734dbfcf.0002.02/DOC_1'},
#   'expr_title': {'type': 'literal',
#    'value': 'Opinion of Advocate General Sharpston delivered on 13 March 2008. # Ecotrade SpA v Agenzia delle Entrate - Ufficio di Genova 3. # Reference for a preliminary ruling: Commissione tributaria provinciale di Genova - Italy. # Sixth VAT Directive - Reverse charge procedure - Right to deduct - Time-bar - Irregularity in accounts and tax returns affecting transactions subject to the reverse charge procedure. # Joined cases C-95/07 and C-96/07.'},
#   'date': {'type': 'typed-literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#date',
#    'value': '2008-03-13'},
#   'class': {'type': 'uri',
#    'value': 'http://publications.europa.eu/ontology/cdm#measure_national_implementing'},
#   'className': {'type': 'literal', 'value': 'measure_national_implementing'},
#   'authorName': {'type': 'literal',
#    'xml:lang': 'en',
#    'value': 'Court of Justice'}},
#  {'item': {'type': 'uri',
#    'value': 'http://publications.europa.eu/resource/cellar/ea3bdcba-e537-4749-b2dc-4457734dbfcf.0002.02/DOC_1'},
#   'expr_title': {'type': 'literal',
#    'value': 'Opinion of Advocate General Sharpston delivered on 13 March 2008. # Ecotrade SpA v Agenzia delle Entrate - Ufficio di Genova 3. # Reference for a preliminary ruling: Commissione tributaria provinciale di Genova - Italy. # Sixth VAT Directive - Reverse charge procedure - Right to deduct - Time-bar - Irregularity in accounts and tax returns affecting transactions subject to the reverse charge procedure. # Joined cases C-95/07 and C-96/07.'},
#   'date': {'type': 'typed-literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#date',
#    'value': '2008-03-13'},
#   'class': {'type': 'uri',
#    'value': 'http://publications.europa.eu/ontology/cdm#official-journal'},
#   'className': {'type': 'literal', 'value': 'official-journal'},
#   'authorName': {'type': 'literal',
#    'xml:lang': 'en',
#    'value': 'Court of Justice'}},
#  {'item': {'type': 'uri',
#    'value': 'http://publications.europa.eu/resource/cellar/ea3bdcba-e537-4749-b2dc-4457734dbfcf.0002.02/DOC_1'},
#   'expr_title': {'type': 'literal',
#    'value': 'Opinion of Advocate General Sharpston delivered on 13 March 2008. # Ecotrade SpA v Agenzia delle Entrate - Ufficio di Genova 3. # Reference for a preliminary ruling: Commissione tributaria provinciale di Genova - Italy. # Sixth VAT Directive - Reverse charge procedure - Right to deduct - Time-bar - Irregularity in accounts and tax returns affecting transactions subject to the reverse charge procedure. # Joined cases C-95/07 and C-96/07.'},
#   'date': {'type': 'typed-literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#date',
#    'value': '2008-03-13'},
#   'class': {'type': 'uri',
#    'value': 'http://publications.europa.eu/ontology/cdm#oj_c'},
#   'className': {'type': 'literal', 'value': 'oj_c'},
#   'authorName': {'type': 'literal',
#    'xml:lang': 'en',
#    'value': 'Court of Justice'}},
#  {'item': {'type': 'uri',
#    'value': 'http://publications.europa.eu/resource/cellar/ea3bdcba-e537-4749-b2dc-4457734dbfcf.0002.02/DOC_1'},
#   'expr_title': {'type': 'literal',
#    'value': 'Opinion of Advocate General Sharpston delivered on 13 March 2008. # Ecotrade SpA v Agenzia delle Entrate - Ufficio di Genova 3. # Reference for a preliminary ruling: Commissione tributaria provinciale di Genova - Italy. # Sixth VAT Directive - Reverse charge procedure - Right to deduct - Time-bar - Irregularity in accounts and tax returns affecting transactions subject to the reverse charge procedure. # Joined cases C-95/07 and C-96/07.'},
#   'date': {'type': 'typed-literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#date',
#    'value': '2008-03-13'},
#   'class': {'type': 'uri',
#    'value': 'http://publications.europa.eu/ontology/cdm#question_parliamentary'},
#   'className': {'type': 'literal', 'value': 'question_parliamentary'},
#   'authorName': {'type': 'literal',
#    'xml:lang': 'en',
#    'value': 'Court of Justice'}},
#  {'item': {'type': 'uri',
#    'value': 'http://publications.europa.eu/resource/cellar/ea3bdcba-e537-4749-b2dc-4457734dbfcf.0002.02/DOC_1'},
#   'expr_title': {'type': 'literal',
#    'value': 'Opinion of Advocate General Sharpston delivered on 13 March 2008. # Ecotrade SpA v Agenzia delle Entrate - Ufficio di Genova 3. # Reference for a preliminary ruling: Commissione tributaria provinciale di Genova - Italy. # Sixth VAT Directive - Reverse charge procedure - Right to deduct - Time-bar - Irregularity in accounts and tax returns affecting transactions subject to the reverse charge procedure. # Joined cases C-95/07 and C-96/07.'},
#   'date': {'type': 'typed-literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#date',
#    'value': '2008-03-13'},
#   'class': {'type': 'uri',
#    'value': 'http://publications.europa.eu/ontology/cdm#treaty'},
#   'className': {'type': 'literal', 'value': 'treaty'},
#   'authorName': {'type': 'literal',
#    'xml:lang': 'en',
#    'value': 'Court of Justice'}},
#  {'item': {'type': 'uri',
#    'value': 'http://publications.europa.eu/resource/cellar/ea3bdcba-e537-4749-b2dc-4457734dbfcf.0002.02/DOC_1'},
#   'expr_title': {'type': 'literal',
#    'value': 'Opinion of Advocate General Sharpston delivered on 13 March 2008. # Ecotrade SpA v Agenzia delle Entrate - Ufficio di Genova 3. # Reference for a preliminary ruling: Commissione tributaria provinciale di Genova - Italy. # Sixth VAT Directive - Reverse charge procedure - Right to deduct - Time-bar - Irregularity in accounts and tax returns affecting transactions subject to the reverse charge procedure. # Joined cases C-95/07 and C-96/07.'},
#   'date': {'type': 'typed-literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#date',
#    'value': '2008-03-13'},
#   'class': {'type': 'uri',
#    'value': 'http://publications.europa.eu/ontology/cdm#document-budgetary'},
#   'className': {'type': 'literal', 'value': 'document-budgetary'},
#   'authorName': {'type': 'literal',
#    'xml:lang': 'en',
#    'value': 'Court of Justice'}},
#  {'item': {'type': 'uri',
#    'value': 'http://publications.europa.eu/resource/cellar/ea3bdcba-e537-4749-b2dc-4457734dbfcf.0002.02/DOC_1'},
#   'expr_title': {'type': 'literal',
#    'value': 'Opinion of Advocate General Sharpston delivered on 13 March 2008. # Ecotrade SpA v Agenzia delle Entrate - Ufficio di Genova 3. # Reference for a preliminary ruling: Commissione tributaria provinciale di Genova - Italy. # Sixth VAT Directive - Reverse charge procedure - Right to deduct - Time-bar - Irregularity in accounts and tax returns affecting transactions subject to the reverse charge procedure. # Joined cases C-95/07 and C-96/07.'},
#   'date': {'type': 'typed-literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#date',
#    'value': '2008-03-13'},
#   'class': {'type': 'uri',
#    'value': 'http://publications.europa.eu/ontology/cdm#document-ec'},
#   'className': {'type': 'literal', 'value': 'document-ec'},
#   'authorName': {'type': 'literal',
#    'xml:lang': 'en',
#    'value': 'Court of Justice'}},
#  {'item': {'type': 'uri',
#    'value': 'http://publications.europa.eu/resource/cellar/3d4572e0-3dcd-432d-85ad-ad918607176b.0020.02/DOC_1'},
#   'expr_title': {'type': 'typed-literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#    'value': 'Regulation (EU) No 305/2011 of the European Parliament and of the Council of 9 March 2011 laying down harmonised conditions for the marketing of construction products and repealing Council Directive 89/106/EEC (Text with EEA relevance) '},
#   'date': {'type': 'typed-literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#date',
#    'value': '2014-06-16'},
#   'class': {'type': 'uri',
#    'value': 'http://publications.europa.eu/ontology/cdm#act_consolidated'},
#   'className': {'type': 'literal', 'value': 'act_consolidated'},
#   'authorName': {'type': 'literal',
#    'xml:lang': 'en',
#    'value': 'Provisional data'}},
#  {'item': {'type': 'uri',
#    'value': 'http://publications.europa.eu/resource/cellar/3d4572e0-3dcd-432d-85ad-ad918607176b.0020.02/DOC_1'},
#   'expr_title': {'type': 'typed-literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#    'value': 'Regulation (EU) No 305/2011 of the European Parliament and of the Council of 9 March 2011 laying down harmonised conditions for the marketing of construction products and repealing Council Directive 89/106/EEC (Text with EEA relevance) '},
#   'date': {'type': 'typed-literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#date',
#    'value': '2014-06-16'},
#   'class': {'type': 'uri',
#    'value': 'http://publications.europa.eu/ontology/cdm#act_preparatory'},
#   'className': {'type': 'literal', 'value': 'act_preparatory'},
#   'authorName': {'type': 'literal',
#    'xml:lang': 'en',
#    'value': 'Provisional data'}},
#  {'item': {'type': 'uri',
#    'value': 'http://publications.europa.eu/resource/cellar/3d4572e0-3dcd-432d-85ad-ad918607176b.0020.02/DOC_1'},
#   'expr_title': {'type': 'typed-literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#    'value': 'Regulation (EU) No 305/2011 of the European Parliament and of the Council of 9 March 2011 laying down harmonised conditions for the marketing of construction products and repealing Council Directive 89/106/EEC (Text with EEA relevance) '},
#   'date': {'type': 'typed-literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#date',
#    'value': '2014-06-16'},
#   'class': {'type': 'uri',
#    'value': 'http://publications.europa.eu/ontology/cdm#agreement_international'},
#   'className': {'type': 'literal', 'value': 'agreement_international'},
#   'authorName': {'type': 'literal',
#    'xml:lang': 'en',
#    'value': 'Provisional data'}},
#  {'item': {'type': 'uri',
#    'value': 'http://publications.europa.eu/resource/cellar/3d4572e0-3dcd-432d-85ad-ad918607176b.0020.02/DOC_1'},
#   'expr_title': {'type': 'typed-literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#    'value': 'Regulation (EU) No 305/2011 of the European Parliament and of the Council of 9 March 2011 laying down harmonised conditions for the marketing of construction products and repealing Council Directive 89/106/EEC (Text with EEA relevance) '},
#   'date': {'type': 'typed-literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#date',
#    'value': '2014-06-16'},
#   'class': {'type': 'uri',
#    'value': 'http://publications.europa.eu/ontology/cdm#case-law'},
#   'className': {'type': 'literal', 'value': 'case-law'},
#   'authorName': {'type': 'literal',
#    'xml:lang': 'en',
#    'value': 'Provisional data'}},
#  {'item': {'type': 'uri',
#    'value': 'http://publications.europa.eu/resource/cellar/3d4572e0-3dcd-432d-85ad-ad918607176b.0020.02/DOC_1'},
#   'expr_title': {'type': 'typed-literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#    'value': 'Regulation (EU) No 305/2011 of the European Parliament and of the Council of 9 March 2011 laying down harmonised conditions for the marketing of construction products and repealing Council Directive 89/106/EEC (Text with EEA relevance) '},
#   'date': {'type': 'typed-literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#date',
#    'value': '2014-06-16'},
#   'class': {'type': 'uri',
#    'value': 'http://publications.europa.eu/ontology/cdm#document_cjeu'},
#   'className': {'type': 'literal', 'value': 'document_cjeu'},
#   'authorName': {'type': 'literal',
#    'xml:lang': 'en',
#    'value': 'Provisional data'}},
#  {'item': {'type': 'uri',
#    'value': 'http://publications.europa.eu/resource/cellar/3d4572e0-3dcd-432d-85ad-ad918607176b.0020.02/DOC_1'},
#   'expr_title': {'type': 'typed-literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#    'value': 'Regulation (EU) No 305/2011 of the European Parliament and of the Council of 9 March 2011 laying down harmonised conditions for the marketing of construction products and repealing Council Directive 89/106/EEC (Text with EEA relevance) '},
#   'date': {'type': 'typed-literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#date',
#    'value': '2014-06-16'},
#   'class': {'type': 'uri',
#    'value': 'http://publications.europa.eu/ontology/cdm#document_efta'},
#   'className': {'type': 'literal', 'value': 'document_efta'},
#   'authorName': {'type': 'literal',
#    'xml:lang': 'en',
#    'value': 'Provisional data'}},
#  {'item': {'type': 'uri',
#    'value': 'http://publications.europa.eu/resource/cellar/3d4572e0-3dcd-432d-85ad-ad918607176b.0020.02/DOC_1'},
#   'expr_title': {'type': 'typed-literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#    'value': 'Regulation (EU) No 305/2011 of the European Parliament and of the Council of 9 March 2011 laying down harmonised conditions for the marketing of construction products and repealing Council Directive 89/106/EEC (Text with EEA relevance) '},
#   'date': {'type': 'typed-literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#date',
#    'value': '2014-06-16'},
#   'class': {'type': 'uri',
#    'value': 'http://publications.europa.eu/ontology/cdm#fragment_resource_legal'},
#   'className': {'type': 'literal', 'value': 'fragment_resource_legal'},
#   'authorName': {'type': 'literal',
#    'xml:lang': 'en',
#    'value': 'Provisional data'}},
#  {'item': {'type': 'uri',
#    'value': 'http://publications.europa.eu/resource/cellar/3d4572e0-3dcd-432d-85ad-ad918607176b.0020.02/DOC_1'},
#   'expr_title': {'type': 'typed-literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#    'value': 'Regulation (EU) No 305/2011 of the European Parliament and of the Council of 9 March 2011 laying down harmonised conditions for the marketing of construction products and repealing Council Directive 89/106/EEC (Text with EEA relevance) '},
#   'date': {'type': 'typed-literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#date',
#    'value': '2014-06-16'},
#   'class': {'type': 'uri',
#    'value': 'http://publications.europa.eu/ontology/cdm#legislation_complementary'},
#   'className': {'type': 'literal', 'value': 'legislation_complementary'},
#   'authorName': {'type': 'literal',
#    'xml:lang': 'en',
#    'value': 'Provisional data'}},
#  {'item': {'type': 'uri',
#    'value': 'http://publications.europa.eu/resource/cellar/3d4572e0-3dcd-432d-85ad-ad918607176b.0020.02/DOC_1'},
#   'expr_title': {'type': 'typed-literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#    'value': 'Regulation (EU) No 305/2011 of the European Parliament and of the Council of 9 March 2011 laying down harmonised conditions for the marketing of construction products and repealing Council Directive 89/106/EEC (Text with EEA relevance) '},
#   'date': {'type': 'typed-literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#date',
#    'value': '2014-06-16'},
#   'class': {'type': 'uri',
#    'value': 'http://publications.europa.eu/ontology/cdm#legislation_secondary'},
#   'className': {'type': 'literal', 'value': 'legislation_secondary'},
#   'authorName': {'type': 'literal',
#    'xml:lang': 'en',
#    'value': 'Provisional data'}},
#  {'item': {'type': 'uri',
#    'value': 'http://publications.europa.eu/resource/cellar/3d4572e0-3dcd-432d-85ad-ad918607176b.0020.02/DOC_1'},
#   'expr_title': {'type': 'typed-literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#    'value': 'Regulation (EU) No 305/2011 of the European Parliament and of the Council of 9 March 2011 laying down harmonised conditions for the marketing of construction products and repealing Council Directive 89/106/EEC (Text with EEA relevance) '},
#   'date': {'type': 'typed-literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#date',
#    'value': '2014-06-16'},
#   'class': {'type': 'uri',
#    'value': 'http://publications.europa.eu/ontology/cdm#measure_national_implementing'},
#   'className': {'type': 'literal', 'value': 'measure_national_implementing'},
#   'authorName': {'type': 'literal',
#    'xml:lang': 'en',
#    'value': 'Provisional data'}},
#  {'item': {'type': 'uri',
#    'value': 'http://publications.europa.eu/resource/cellar/3d4572e0-3dcd-432d-85ad-ad918607176b.0020.02/DOC_1'},
#   'expr_title': {'type': 'typed-literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#    'value': 'Regulation (EU) No 305/2011 of the European Parliament and of the Council of 9 March 2011 laying down harmonised conditions for the marketing of construction products and repealing Council Directive 89/106/EEC (Text with EEA relevance) '},
#   'date': {'type': 'typed-literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#date',
#    'value': '2014-06-16'},
#   'class': {'type': 'uri',
#    'value': 'http://publications.europa.eu/ontology/cdm#official-journal'},
#   'className': {'type': 'literal', 'value': 'official-journal'},
#   'authorName': {'type': 'literal',
#    'xml:lang': 'en',
#    'value': 'Provisional data'}},
#  {'item': {'type': 'uri',
#    'value': 'http://publications.europa.eu/resource/cellar/3d4572e0-3dcd-432d-85ad-ad918607176b.0020.02/DOC_1'},
#   'expr_title': {'type': 'typed-literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#    'value': 'Regulation (EU) No 305/2011 of the European Parliament and of the Council of 9 March 2011 laying down harmonised conditions for the marketing of construction products and repealing Council Directive 89/106/EEC (Text with EEA relevance) '},
#   'date': {'type': 'typed-literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#date',
#    'value': '2014-06-16'},
#   'class': {'type': 'uri',
#    'value': 'http://publications.europa.eu/ontology/cdm#oj_c'},
#   'className': {'type': 'literal', 'value': 'oj_c'},
#   'authorName': {'type': 'literal',
#    'xml:lang': 'en',
#    'value': 'Provisional data'}},
#  {'item': {'type': 'uri',
#    'value': 'http://publications.europa.eu/resource/cellar/3d4572e0-3dcd-432d-85ad-ad918607176b.0020.02/DOC_1'},
#   'expr_title': {'type': 'typed-literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#    'value': 'Regulation (EU) No 305/2011 of the European Parliament and of the Council of 9 March 2011 laying down harmonised conditions for the marketing of construction products and repealing Council Directive 89/106/EEC (Text with EEA relevance) '},
#   'date': {'type': 'typed-literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#date',
#    'value': '2014-06-16'},
#   'class': {'type': 'uri',
#    'value': 'http://publications.europa.eu/ontology/cdm#question_parliamentary'},
#   'className': {'type': 'literal', 'value': 'question_parliamentary'},
#   'authorName': {'type': 'literal',
#    'xml:lang': 'en',
#    'value': 'Provisional data'}},
#  {'item': {'type': 'uri',
#    'value': 'http://publications.europa.eu/resource/cellar/3d4572e0-3dcd-432d-85ad-ad918607176b.0020.02/DOC_1'},
#   'expr_title': {'type': 'typed-literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#    'value': 'Regulation (EU) No 305/2011 of the European Parliament and of the Council of 9 March 2011 laying down harmonised conditions for the marketing of construction products and repealing Council Directive 89/106/EEC (Text with EEA relevance) '},
#   'date': {'type': 'typed-literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#date',
#    'value': '2014-06-16'},
#   'class': {'type': 'uri',
#    'value': 'http://publications.europa.eu/ontology/cdm#treaty'},
#   'className': {'type': 'literal', 'value': 'treaty'},
#   'authorName': {'type': 'literal',
#    'xml:lang': 'en',
#    'value': 'Provisional data'}},
#  {'item': {'type': 'uri',
#    'value': 'http://publications.europa.eu/resource/cellar/3d4572e0-3dcd-432d-85ad-ad918607176b.0020.02/DOC_1'},
#   'expr_title': {'type': 'typed-literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#    'value': 'Regulation (EU) No 305/2011 of the European Parliament and of the Council of 9 March 2011 laying down harmonised conditions for the marketing of construction products and repealing Council Directive 89/106/EEC (Text with EEA relevance) '},
#   'date': {'type': 'typed-literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#date',
#    'value': '2014-06-16'},
#   'class': {'type': 'uri',
#    'value': 'http://publications.europa.eu/ontology/cdm#document-budgetary'},
#   'className': {'type': 'literal', 'value': 'document-budgetary'},
#   'authorName': {'type': 'literal',
#    'xml:lang': 'en',
#    'value': 'Provisional data'}},
#  {'item': {'type': 'uri',
#    'value': 'http://publications.europa.eu/resource/cellar/3d4572e0-3dcd-432d-85ad-ad918607176b.0020.02/DOC_1'},
#   'expr_title': {'type': 'typed-literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#    'value': 'Regulation (EU) No 305/2011 of the European Parliament and of the Council of 9 March 2011 laying down harmonised conditions for the marketing of construction products and repealing Council Directive 89/106/EEC (Text with EEA relevance) '},
#   'date': {'type': 'typed-literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#date',
#    'value': '2014-06-16'},
#   'class': {'type': 'uri',
#    'value': 'http://publications.europa.eu/ontology/cdm#document-ec'},
#   'className': {'type': 'literal', 'value': 'document-ec'},
#   'authorName': {'type': 'literal',
#    'xml:lang': 'en',
#    'value': 'Provisional data'}}]

# %%
for result in results["results"]["bindings"]:
    print(result["celex"]["value"])
# Out:
# ---------------------------------------------------------------------------
#
# KeyError                                  Traceback (most recent call last)
#
# Cell In[24], line 2
#
#       1 for result in results["results"]["bindings"]:
#
# ----> 2     print(result["celex"]["value"])
#
#
#
# KeyError: 'celex'

# %%
def clean_results(results):
    results_clean = [
        {k:v["value"] for k,v in item.items()}
        for item in results["results"]["bindings"]
    ]
    results_clean = pd.DataFrame(results_clean)
    return results_clean

# %%
items = clean_results(results)
print(items.shape[0])
items.head(3)
# Out:
# 32
#                                                 item  \
# 0  http://publications.europa.eu/resource/cellar/...
# 1  http://publications.europa.eu/resource/cellar/...
# 2  http://publications.europa.eu/resource/cellar/...
#
#                                           expr_title        date  \
# 0  Opinion of Advocate General Sharpston delivere...  2008-03-13
# 1  Opinion of Advocate General Sharpston delivere...  2008-03-13
# 2  Opinion of Advocate General Sharpston delivere...  2008-03-13
#
#                                                class                className  \
# 0  http://publications.europa.eu/ontology/cdm#act...         act_consolidated
# 1  http://publications.europa.eu/ontology/cdm#act...          act_preparatory
# 2  http://publications.europa.eu/ontology/cdm#agr...  agreement_international
#
#          authorName
# 0  Court of Justice
# 1  Court of Justice
# 2  Court of Justice

# %%
items['item'].to_list()
# Out:
# ['http://publications.europa.eu/resource/cellar/ea3bdcba-e537-4749-b2dc-4457734dbfcf.0002.02/DOC_1',
#  'http://publications.europa.eu/resource/cellar/ea3bdcba-e537-4749-b2dc-4457734dbfcf.0002.02/DOC_1',
#  'http://publications.europa.eu/resource/cellar/ea3bdcba-e537-4749-b2dc-4457734dbfcf.0002.02/DOC_1',
#  'http://publications.europa.eu/resource/cellar/ea3bdcba-e537-4749-b2dc-4457734dbfcf.0002.02/DOC_1',
#  'http://publications.europa.eu/resource/cellar/ea3bdcba-e537-4749-b2dc-4457734dbfcf.0002.02/DOC_1',
#  'http://publications.europa.eu/resource/cellar/ea3bdcba-e537-4749-b2dc-4457734dbfcf.0002.02/DOC_1',
#  'http://publications.europa.eu/resource/cellar/ea3bdcba-e537-4749-b2dc-4457734dbfcf.0002.02/DOC_1',
#  'http://publications.europa.eu/resource/cellar/ea3bdcba-e537-4749-b2dc-4457734dbfcf.0002.02/DOC_1',
#  'http://publications.europa.eu/resource/cellar/ea3bdcba-e537-4749-b2dc-4457734dbfcf.0002.02/DOC_1',
#  'http://publications.europa.eu/resource/cellar/ea3bdcba-e537-4749-b2dc-4457734dbfcf.0002.02/DOC_1',
#  'http://publications.europa.eu/resource/cellar/ea3bdcba-e537-4749-b2dc-4457734dbfcf.0002.02/DOC_1',
#  'http://publications.europa.eu/resource/cellar/ea3bdcba-e537-4749-b2dc-4457734dbfcf.0002.02/DOC_1',
#  'http://publications.europa.eu/resource/cellar/ea3bdcba-e537-4749-b2dc-4457734dbfcf.0002.02/DOC_1',
#  'http://publications.europa.eu/resource/cellar/ea3bdcba-e537-4749-b2dc-4457734dbfcf.0002.02/DOC_1',
#  'http://publications.europa.eu/resource/cellar/ea3bdcba-e537-4749-b2dc-4457734dbfcf.0002.02/DOC_1',
#  'http://publications.europa.eu/resource/cellar/ea3bdcba-e537-4749-b2dc-4457734dbfcf.0002.02/DOC_1',
#  'http://publications.europa.eu/resource/cellar/3d4572e0-3dcd-432d-85ad-ad918607176b.0020.02/DOC_1',
#  'http://publications.europa.eu/resource/cellar/3d4572e0-3dcd-432d-85ad-ad918607176b.0020.02/DOC_1',
#  'http://publications.europa.eu/resource/cellar/3d4572e0-3dcd-432d-85ad-ad918607176b.0020.02/DOC_1',
#  'http://publications.europa.eu/resource/cellar/3d4572e0-3dcd-432d-85ad-ad918607176b.0020.02/DOC_1',
#  'http://publications.europa.eu/resource/cellar/3d4572e0-3dcd-432d-85ad-ad918607176b.0020.02/DOC_1',
#  'http://publications.europa.eu/resource/cellar/3d4572e0-3dcd-432d-85ad-ad918607176b.0020.02/DOC_1',
#  'http://publications.europa.eu/resource/cellar/3d4572e0-3dcd-432d-85ad-ad918607176b.0020.02/DOC_1',
#  'http://publications.europa.eu/resource/cellar/3d4572e0-3dcd-432d-85ad-ad918607176b.0020.02/DOC_1',
#  'http://publications.europa.eu/resource/cellar/3d4572e0-3dcd-432d-85ad-ad918607176b.0020.02/DOC_1',
#  'http://publications.europa.eu/resource/cellar/3d4572e0-3dcd-432d-85ad-ad918607176b.0020.02/DOC_1',
#  'http://publications.europa.eu/resource/cellar/3d4572e0-3dcd-432d-85ad-ad918607176b.0020.02/DOC_1',
#  'http://publications.europa.eu/resource/cellar/3d4572e0-3dcd-432d-85ad-ad918607176b.0020.02/DOC_1',
#  'http://publications.europa.eu/resource/cellar/3d4572e0-3dcd-432d-85ad-ad918607176b.0020.02/DOC_1',
#  'http://publications.europa.eu/resource/cellar/3d4572e0-3dcd-432d-85ad-ad918607176b.0020.02/DOC_1',
#  'http://publications.europa.eu/resource/cellar/3d4572e0-3dcd-432d-85ad-ad918607176b.0020.02/DOC_1',
#  'http://publications.europa.eu/resource/cellar/3d4572e0-3dcd-432d-85ad-ad918607176b.0020.02/DOC_1']

# %%
results["results"]["bindings"]
# Out:
# [{'item': {'type': 'uri',
#    'value': 'http://publications.europa.eu/resource/cellar/ea3bdcba-e537-4749-b2dc-4457734dbfcf.0002.02/DOC_1'},
#   'expr_title': {'type': 'literal',
#    'value': 'Opinion of Advocate General Sharpston delivered on 13 March 2008. # Ecotrade SpA v Agenzia delle Entrate - Ufficio di Genova 3. # Reference for a preliminary ruling: Commissione tributaria provinciale di Genova - Italy. # Sixth VAT Directive - Reverse charge procedure - Right to deduct - Time-bar - Irregularity in accounts and tax returns affecting transactions subject to the reverse charge procedure. # Joined cases C-95/07 and C-96/07.'},
#   'date': {'type': 'typed-literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#date',
#    'value': '2008-03-13'},
#   'class': {'type': 'uri',
#    'value': 'http://publications.europa.eu/ontology/cdm#act_consolidated'},
#   'className': {'type': 'literal', 'value': 'act_consolidated'},
#   'authorName': {'type': 'literal',
#    'xml:lang': 'en',
#    'value': 'Court of Justice'}},
#  {'item': {'type': 'uri',
#    'value': 'http://publications.europa.eu/resource/cellar/ea3bdcba-e537-4749-b2dc-4457734dbfcf.0002.02/DOC_1'},
#   'expr_title': {'type': 'literal',
#    'value': 'Opinion of Advocate General Sharpston delivered on 13 March 2008. # Ecotrade SpA v Agenzia delle Entrate - Ufficio di Genova 3. # Reference for a preliminary ruling: Commissione tributaria provinciale di Genova - Italy. # Sixth VAT Directive - Reverse charge procedure - Right to deduct - Time-bar - Irregularity in accounts and tax returns affecting transactions subject to the reverse charge procedure. # Joined cases C-95/07 and C-96/07.'},
#   'date': {'type': 'typed-literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#date',
#    'value': '2008-03-13'},
#   'class': {'type': 'uri',
#    'value': 'http://publications.europa.eu/ontology/cdm#act_preparatory'},
#   'className': {'type': 'literal', 'value': 'act_preparatory'},
#   'authorName': {'type': 'literal',
#    'xml:lang': 'en',
#    'value': 'Court of Justice'}},
#  {'item': {'type': 'uri',
#    'value': 'http://publications.europa.eu/resource/cellar/ea3bdcba-e537-4749-b2dc-4457734dbfcf.0002.02/DOC_1'},
#   'expr_title': {'type': 'literal',
#    'value': 'Opinion of Advocate General Sharpston delivered on 13 March 2008. # Ecotrade SpA v Agenzia delle Entrate - Ufficio di Genova 3. # Reference for a preliminary ruling: Commissione tributaria provinciale di Genova - Italy. # Sixth VAT Directive - Reverse charge procedure - Right to deduct - Time-bar - Irregularity in accounts and tax returns affecting transactions subject to the reverse charge procedure. # Joined cases C-95/07 and C-96/07.'},
#   'date': {'type': 'typed-literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#date',
#    'value': '2008-03-13'},
#   'class': {'type': 'uri',
#    'value': 'http://publications.europa.eu/ontology/cdm#agreement_international'},
#   'className': {'type': 'literal', 'value': 'agreement_international'},
#   'authorName': {'type': 'literal',
#    'xml:lang': 'en',
#    'value': 'Court of Justice'}},
#  {'item': {'type': 'uri',
#    'value': 'http://publications.europa.eu/resource/cellar/ea3bdcba-e537-4749-b2dc-4457734dbfcf.0002.02/DOC_1'},
#   'expr_title': {'type': 'literal',
#    'value': 'Opinion of Advocate General Sharpston delivered on 13 March 2008. # Ecotrade SpA v Agenzia delle Entrate - Ufficio di Genova 3. # Reference for a preliminary ruling: Commissione tributaria provinciale di Genova - Italy. # Sixth VAT Directive - Reverse charge procedure - Right to deduct - Time-bar - Irregularity in accounts and tax returns affecting transactions subject to the reverse charge procedure. # Joined cases C-95/07 and C-96/07.'},
#   'date': {'type': 'typed-literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#date',
#    'value': '2008-03-13'},
#   'class': {'type': 'uri',
#    'value': 'http://publications.europa.eu/ontology/cdm#case-law'},
#   'className': {'type': 'literal', 'value': 'case-law'},
#   'authorName': {'type': 'literal',
#    'xml:lang': 'en',
#    'value': 'Court of Justice'}},
#  {'item': {'type': 'uri',
#    'value': 'http://publications.europa.eu/resource/cellar/ea3bdcba-e537-4749-b2dc-4457734dbfcf.0002.02/DOC_1'},
#   'expr_title': {'type': 'literal',
#    'value': 'Opinion of Advocate General Sharpston delivered on 13 March 2008. # Ecotrade SpA v Agenzia delle Entrate - Ufficio di Genova 3. # Reference for a preliminary ruling: Commissione tributaria provinciale di Genova - Italy. # Sixth VAT Directive - Reverse charge procedure - Right to deduct - Time-bar - Irregularity in accounts and tax returns affecting transactions subject to the reverse charge procedure. # Joined cases C-95/07 and C-96/07.'},
#   'date': {'type': 'typed-literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#date',
#    'value': '2008-03-13'},
#   'class': {'type': 'uri',
#    'value': 'http://publications.europa.eu/ontology/cdm#document_cjeu'},
#   'className': {'type': 'literal', 'value': 'document_cjeu'},
#   'authorName': {'type': 'literal',
#    'xml:lang': 'en',
#    'value': 'Court of Justice'}},
#  {'item': {'type': 'uri',
#    'value': 'http://publications.europa.eu/resource/cellar/ea3bdcba-e537-4749-b2dc-4457734dbfcf.0002.02/DOC_1'},
#   'expr_title': {'type': 'literal',
#    'value': 'Opinion of Advocate General Sharpston delivered on 13 March 2008. # Ecotrade SpA v Agenzia delle Entrate - Ufficio di Genova 3. # Reference for a preliminary ruling: Commissione tributaria provinciale di Genova - Italy. # Sixth VAT Directive - Reverse charge procedure - Right to deduct - Time-bar - Irregularity in accounts and tax returns affecting transactions subject to the reverse charge procedure. # Joined cases C-95/07 and C-96/07.'},
#   'date': {'type': 'typed-literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#date',
#    'value': '2008-03-13'},
#   'class': {'type': 'uri',
#    'value': 'http://publications.europa.eu/ontology/cdm#document_efta'},
#   'className': {'type': 'literal', 'value': 'document_efta'},
#   'authorName': {'type': 'literal',
#    'xml:lang': 'en',
#    'value': 'Court of Justice'}},
#  {'item': {'type': 'uri',
#    'value': 'http://publications.europa.eu/resource/cellar/ea3bdcba-e537-4749-b2dc-4457734dbfcf.0002.02/DOC_1'},
#   'expr_title': {'type': 'literal',
#    'value': 'Opinion of Advocate General Sharpston delivered on 13 March 2008. # Ecotrade SpA v Agenzia delle Entrate - Ufficio di Genova 3. # Reference for a preliminary ruling: Commissione tributaria provinciale di Genova - Italy. # Sixth VAT Directive - Reverse charge procedure - Right to deduct - Time-bar - Irregularity in accounts and tax returns affecting transactions subject to the reverse charge procedure. # Joined cases C-95/07 and C-96/07.'},
#   'date': {'type': 'typed-literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#date',
#    'value': '2008-03-13'},
#   'class': {'type': 'uri',
#    'value': 'http://publications.europa.eu/ontology/cdm#fragment_resource_legal'},
#   'className': {'type': 'literal', 'value': 'fragment_resource_legal'},
#   'authorName': {'type': 'literal',
#    'xml:lang': 'en',
#    'value': 'Court of Justice'}},
#  {'item': {'type': 'uri',
#    'value': 'http://publications.europa.eu/resource/cellar/ea3bdcba-e537-4749-b2dc-4457734dbfcf.0002.02/DOC_1'},
#   'expr_title': {'type': 'literal',
#    'value': 'Opinion of Advocate General Sharpston delivered on 13 March 2008. # Ecotrade SpA v Agenzia delle Entrate - Ufficio di Genova 3. # Reference for a preliminary ruling: Commissione tributaria provinciale di Genova - Italy. # Sixth VAT Directive - Reverse charge procedure - Right to deduct - Time-bar - Irregularity in accounts and tax returns affecting transactions subject to the reverse charge procedure. # Joined cases C-95/07 and C-96/07.'},
#   'date': {'type': 'typed-literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#date',
#    'value': '2008-03-13'},
#   'class': {'type': 'uri',
#    'value': 'http://publications.europa.eu/ontology/cdm#legislation_complementary'},
#   'className': {'type': 'literal', 'value': 'legislation_complementary'},
#   'authorName': {'type': 'literal',
#    'xml:lang': 'en',
#    'value': 'Court of Justice'}},
#  {'item': {'type': 'uri',
#    'value': 'http://publications.europa.eu/resource/cellar/ea3bdcba-e537-4749-b2dc-4457734dbfcf.0002.02/DOC_1'},
#   'expr_title': {'type': 'literal',
#    'value': 'Opinion of Advocate General Sharpston delivered on 13 March 2008. # Ecotrade SpA v Agenzia delle Entrate - Ufficio di Genova 3. # Reference for a preliminary ruling: Commissione tributaria provinciale di Genova - Italy. # Sixth VAT Directive - Reverse charge procedure - Right to deduct - Time-bar - Irregularity in accounts and tax returns affecting transactions subject to the reverse charge procedure. # Joined cases C-95/07 and C-96/07.'},
#   'date': {'type': 'typed-literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#date',
#    'value': '2008-03-13'},
#   'class': {'type': 'uri',
#    'value': 'http://publications.europa.eu/ontology/cdm#legislation_secondary'},
#   'className': {'type': 'literal', 'value': 'legislation_secondary'},
#   'authorName': {'type': 'literal',
#    'xml:lang': 'en',
#    'value': 'Court of Justice'}},
#  {'item': {'type': 'uri',
#    'value': 'http://publications.europa.eu/resource/cellar/ea3bdcba-e537-4749-b2dc-4457734dbfcf.0002.02/DOC_1'},
#   'expr_title': {'type': 'literal',
#    'value': 'Opinion of Advocate General Sharpston delivered on 13 March 2008. # Ecotrade SpA v Agenzia delle Entrate - Ufficio di Genova 3. # Reference for a preliminary ruling: Commissione tributaria provinciale di Genova - Italy. # Sixth VAT Directive - Reverse charge procedure - Right to deduct - Time-bar - Irregularity in accounts and tax returns affecting transactions subject to the reverse charge procedure. # Joined cases C-95/07 and C-96/07.'},
#   'date': {'type': 'typed-literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#date',
#    'value': '2008-03-13'},
#   'class': {'type': 'uri',
#    'value': 'http://publications.europa.eu/ontology/cdm#measure_national_implementing'},
#   'className': {'type': 'literal', 'value': 'measure_national_implementing'},
#   'authorName': {'type': 'literal',
#    'xml:lang': 'en',
#    'value': 'Court of Justice'}},
#  {'item': {'type': 'uri',
#    'value': 'http://publications.europa.eu/resource/cellar/ea3bdcba-e537-4749-b2dc-4457734dbfcf.0002.02/DOC_1'},
#   'expr_title': {'type': 'literal',
#    'value': 'Opinion of Advocate General Sharpston delivered on 13 March 2008. # Ecotrade SpA v Agenzia delle Entrate - Ufficio di Genova 3. # Reference for a preliminary ruling: Commissione tributaria provinciale di Genova - Italy. # Sixth VAT Directive - Reverse charge procedure - Right to deduct - Time-bar - Irregularity in accounts and tax returns affecting transactions subject to the reverse charge procedure. # Joined cases C-95/07 and C-96/07.'},
#   'date': {'type': 'typed-literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#date',
#    'value': '2008-03-13'},
#   'class': {'type': 'uri',
#    'value': 'http://publications.europa.eu/ontology/cdm#official-journal'},
#   'className': {'type': 'literal', 'value': 'official-journal'},
#   'authorName': {'type': 'literal',
#    'xml:lang': 'en',
#    'value': 'Court of Justice'}},
#  {'item': {'type': 'uri',
#    'value': 'http://publications.europa.eu/resource/cellar/ea3bdcba-e537-4749-b2dc-4457734dbfcf.0002.02/DOC_1'},
#   'expr_title': {'type': 'literal',
#    'value': 'Opinion of Advocate General Sharpston delivered on 13 March 2008. # Ecotrade SpA v Agenzia delle Entrate - Ufficio di Genova 3. # Reference for a preliminary ruling: Commissione tributaria provinciale di Genova - Italy. # Sixth VAT Directive - Reverse charge procedure - Right to deduct - Time-bar - Irregularity in accounts and tax returns affecting transactions subject to the reverse charge procedure. # Joined cases C-95/07 and C-96/07.'},
#   'date': {'type': 'typed-literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#date',
#    'value': '2008-03-13'},
#   'class': {'type': 'uri',
#    'value': 'http://publications.europa.eu/ontology/cdm#oj_c'},
#   'className': {'type': 'literal', 'value': 'oj_c'},
#   'authorName': {'type': 'literal',
#    'xml:lang': 'en',
#    'value': 'Court of Justice'}},
#  {'item': {'type': 'uri',
#    'value': 'http://publications.europa.eu/resource/cellar/ea3bdcba-e537-4749-b2dc-4457734dbfcf.0002.02/DOC_1'},
#   'expr_title': {'type': 'literal',
#    'value': 'Opinion of Advocate General Sharpston delivered on 13 March 2008. # Ecotrade SpA v Agenzia delle Entrate - Ufficio di Genova 3. # Reference for a preliminary ruling: Commissione tributaria provinciale di Genova - Italy. # Sixth VAT Directive - Reverse charge procedure - Right to deduct - Time-bar - Irregularity in accounts and tax returns affecting transactions subject to the reverse charge procedure. # Joined cases C-95/07 and C-96/07.'},
#   'date': {'type': 'typed-literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#date',
#    'value': '2008-03-13'},
#   'class': {'type': 'uri',
#    'value': 'http://publications.europa.eu/ontology/cdm#question_parliamentary'},
#   'className': {'type': 'literal', 'value': 'question_parliamentary'},
#   'authorName': {'type': 'literal',
#    'xml:lang': 'en',
#    'value': 'Court of Justice'}},
#  {'item': {'type': 'uri',
#    'value': 'http://publications.europa.eu/resource/cellar/ea3bdcba-e537-4749-b2dc-4457734dbfcf.0002.02/DOC_1'},
#   'expr_title': {'type': 'literal',
#    'value': 'Opinion of Advocate General Sharpston delivered on 13 March 2008. # Ecotrade SpA v Agenzia delle Entrate - Ufficio di Genova 3. # Reference for a preliminary ruling: Commissione tributaria provinciale di Genova - Italy. # Sixth VAT Directive - Reverse charge procedure - Right to deduct - Time-bar - Irregularity in accounts and tax returns affecting transactions subject to the reverse charge procedure. # Joined cases C-95/07 and C-96/07.'},
#   'date': {'type': 'typed-literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#date',
#    'value': '2008-03-13'},
#   'class': {'type': 'uri',
#    'value': 'http://publications.europa.eu/ontology/cdm#treaty'},
#   'className': {'type': 'literal', 'value': 'treaty'},
#   'authorName': {'type': 'literal',
#    'xml:lang': 'en',
#    'value': 'Court of Justice'}},
#  {'item': {'type': 'uri',
#    'value': 'http://publications.europa.eu/resource/cellar/ea3bdcba-e537-4749-b2dc-4457734dbfcf.0002.02/DOC_1'},
#   'expr_title': {'type': 'literal',
#    'value': 'Opinion of Advocate General Sharpston delivered on 13 March 2008. # Ecotrade SpA v Agenzia delle Entrate - Ufficio di Genova 3. # Reference for a preliminary ruling: Commissione tributaria provinciale di Genova - Italy. # Sixth VAT Directive - Reverse charge procedure - Right to deduct - Time-bar - Irregularity in accounts and tax returns affecting transactions subject to the reverse charge procedure. # Joined cases C-95/07 and C-96/07.'},
#   'date': {'type': 'typed-literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#date',
#    'value': '2008-03-13'},
#   'class': {'type': 'uri',
#    'value': 'http://publications.europa.eu/ontology/cdm#document-budgetary'},
#   'className': {'type': 'literal', 'value': 'document-budgetary'},
#   'authorName': {'type': 'literal',
#    'xml:lang': 'en',
#    'value': 'Court of Justice'}},
#  {'item': {'type': 'uri',
#    'value': 'http://publications.europa.eu/resource/cellar/ea3bdcba-e537-4749-b2dc-4457734dbfcf.0002.02/DOC_1'},
#   'expr_title': {'type': 'literal',
#    'value': 'Opinion of Advocate General Sharpston delivered on 13 March 2008. # Ecotrade SpA v Agenzia delle Entrate - Ufficio di Genova 3. # Reference for a preliminary ruling: Commissione tributaria provinciale di Genova - Italy. # Sixth VAT Directive - Reverse charge procedure - Right to deduct - Time-bar - Irregularity in accounts and tax returns affecting transactions subject to the reverse charge procedure. # Joined cases C-95/07 and C-96/07.'},
#   'date': {'type': 'typed-literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#date',
#    'value': '2008-03-13'},
#   'class': {'type': 'uri',
#    'value': 'http://publications.europa.eu/ontology/cdm#document-ec'},
#   'className': {'type': 'literal', 'value': 'document-ec'},
#   'authorName': {'type': 'literal',
#    'xml:lang': 'en',
#    'value': 'Court of Justice'}},
#  {'item': {'type': 'uri',
#    'value': 'http://publications.europa.eu/resource/cellar/3d4572e0-3dcd-432d-85ad-ad918607176b.0020.02/DOC_1'},
#   'expr_title': {'type': 'typed-literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#    'value': 'Regulation (EU) No 305/2011 of the European Parliament and of the Council of 9 March 2011 laying down harmonised conditions for the marketing of construction products and repealing Council Directive 89/106/EEC (Text with EEA relevance) '},
#   'date': {'type': 'typed-literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#date',
#    'value': '2014-06-16'},
#   'class': {'type': 'uri',
#    'value': 'http://publications.europa.eu/ontology/cdm#act_consolidated'},
#   'className': {'type': 'literal', 'value': 'act_consolidated'},
#   'authorName': {'type': 'literal',
#    'xml:lang': 'en',
#    'value': 'Provisional data'}},
#  {'item': {'type': 'uri',
#    'value': 'http://publications.europa.eu/resource/cellar/3d4572e0-3dcd-432d-85ad-ad918607176b.0020.02/DOC_1'},
#   'expr_title': {'type': 'typed-literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#    'value': 'Regulation (EU) No 305/2011 of the European Parliament and of the Council of 9 March 2011 laying down harmonised conditions for the marketing of construction products and repealing Council Directive 89/106/EEC (Text with EEA relevance) '},
#   'date': {'type': 'typed-literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#date',
#    'value': '2014-06-16'},
#   'class': {'type': 'uri',
#    'value': 'http://publications.europa.eu/ontology/cdm#act_preparatory'},
#   'className': {'type': 'literal', 'value': 'act_preparatory'},
#   'authorName': {'type': 'literal',
#    'xml:lang': 'en',
#    'value': 'Provisional data'}},
#  {'item': {'type': 'uri',
#    'value': 'http://publications.europa.eu/resource/cellar/3d4572e0-3dcd-432d-85ad-ad918607176b.0020.02/DOC_1'},
#   'expr_title': {'type': 'typed-literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#    'value': 'Regulation (EU) No 305/2011 of the European Parliament and of the Council of 9 March 2011 laying down harmonised conditions for the marketing of construction products and repealing Council Directive 89/106/EEC (Text with EEA relevance) '},
#   'date': {'type': 'typed-literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#date',
#    'value': '2014-06-16'},
#   'class': {'type': 'uri',
#    'value': 'http://publications.europa.eu/ontology/cdm#agreement_international'},
#   'className': {'type': 'literal', 'value': 'agreement_international'},
#   'authorName': {'type': 'literal',
#    'xml:lang': 'en',
#    'value': 'Provisional data'}},
#  {'item': {'type': 'uri',
#    'value': 'http://publications.europa.eu/resource/cellar/3d4572e0-3dcd-432d-85ad-ad918607176b.0020.02/DOC_1'},
#   'expr_title': {'type': 'typed-literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#    'value': 'Regulation (EU) No 305/2011 of the European Parliament and of the Council of 9 March 2011 laying down harmonised conditions for the marketing of construction products and repealing Council Directive 89/106/EEC (Text with EEA relevance) '},
#   'date': {'type': 'typed-literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#date',
#    'value': '2014-06-16'},
#   'class': {'type': 'uri',
#    'value': 'http://publications.europa.eu/ontology/cdm#case-law'},
#   'className': {'type': 'literal', 'value': 'case-law'},
#   'authorName': {'type': 'literal',
#    'xml:lang': 'en',
#    'value': 'Provisional data'}},
#  {'item': {'type': 'uri',
#    'value': 'http://publications.europa.eu/resource/cellar/3d4572e0-3dcd-432d-85ad-ad918607176b.0020.02/DOC_1'},
#   'expr_title': {'type': 'typed-literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#    'value': 'Regulation (EU) No 305/2011 of the European Parliament and of the Council of 9 March 2011 laying down harmonised conditions for the marketing of construction products and repealing Council Directive 89/106/EEC (Text with EEA relevance) '},
#   'date': {'type': 'typed-literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#date',
#    'value': '2014-06-16'},
#   'class': {'type': 'uri',
#    'value': 'http://publications.europa.eu/ontology/cdm#document_cjeu'},
#   'className': {'type': 'literal', 'value': 'document_cjeu'},
#   'authorName': {'type': 'literal',
#    'xml:lang': 'en',
#    'value': 'Provisional data'}},
#  {'item': {'type': 'uri',
#    'value': 'http://publications.europa.eu/resource/cellar/3d4572e0-3dcd-432d-85ad-ad918607176b.0020.02/DOC_1'},
#   'expr_title': {'type': 'typed-literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#    'value': 'Regulation (EU) No 305/2011 of the European Parliament and of the Council of 9 March 2011 laying down harmonised conditions for the marketing of construction products and repealing Council Directive 89/106/EEC (Text with EEA relevance) '},
#   'date': {'type': 'typed-literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#date',
#    'value': '2014-06-16'},
#   'class': {'type': 'uri',
#    'value': 'http://publications.europa.eu/ontology/cdm#document_efta'},
#   'className': {'type': 'literal', 'value': 'document_efta'},
#   'authorName': {'type': 'literal',
#    'xml:lang': 'en',
#    'value': 'Provisional data'}},
#  {'item': {'type': 'uri',
#    'value': 'http://publications.europa.eu/resource/cellar/3d4572e0-3dcd-432d-85ad-ad918607176b.0020.02/DOC_1'},
#   'expr_title': {'type': 'typed-literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#    'value': 'Regulation (EU) No 305/2011 of the European Parliament and of the Council of 9 March 2011 laying down harmonised conditions for the marketing of construction products and repealing Council Directive 89/106/EEC (Text with EEA relevance) '},
#   'date': {'type': 'typed-literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#date',
#    'value': '2014-06-16'},
#   'class': {'type': 'uri',
#    'value': 'http://publications.europa.eu/ontology/cdm#fragment_resource_legal'},
#   'className': {'type': 'literal', 'value': 'fragment_resource_legal'},
#   'authorName': {'type': 'literal',
#    'xml:lang': 'en',
#    'value': 'Provisional data'}},
#  {'item': {'type': 'uri',
#    'value': 'http://publications.europa.eu/resource/cellar/3d4572e0-3dcd-432d-85ad-ad918607176b.0020.02/DOC_1'},
#   'expr_title': {'type': 'typed-literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#    'value': 'Regulation (EU) No 305/2011 of the European Parliament and of the Council of 9 March 2011 laying down harmonised conditions for the marketing of construction products and repealing Council Directive 89/106/EEC (Text with EEA relevance) '},
#   'date': {'type': 'typed-literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#date',
#    'value': '2014-06-16'},
#   'class': {'type': 'uri',
#    'value': 'http://publications.europa.eu/ontology/cdm#legislation_complementary'},
#   'className': {'type': 'literal', 'value': 'legislation_complementary'},
#   'authorName': {'type': 'literal',
#    'xml:lang': 'en',
#    'value': 'Provisional data'}},
#  {'item': {'type': 'uri',
#    'value': 'http://publications.europa.eu/resource/cellar/3d4572e0-3dcd-432d-85ad-ad918607176b.0020.02/DOC_1'},
#   'expr_title': {'type': 'typed-literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#    'value': 'Regulation (EU) No 305/2011 of the European Parliament and of the Council of 9 March 2011 laying down harmonised conditions for the marketing of construction products and repealing Council Directive 89/106/EEC (Text with EEA relevance) '},
#   'date': {'type': 'typed-literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#date',
#    'value': '2014-06-16'},
#   'class': {'type': 'uri',
#    'value': 'http://publications.europa.eu/ontology/cdm#legislation_secondary'},
#   'className': {'type': 'literal', 'value': 'legislation_secondary'},
#   'authorName': {'type': 'literal',
#    'xml:lang': 'en',
#    'value': 'Provisional data'}},
#  {'item': {'type': 'uri',
#    'value': 'http://publications.europa.eu/resource/cellar/3d4572e0-3dcd-432d-85ad-ad918607176b.0020.02/DOC_1'},
#   'expr_title': {'type': 'typed-literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#    'value': 'Regulation (EU) No 305/2011 of the European Parliament and of the Council of 9 March 2011 laying down harmonised conditions for the marketing of construction products and repealing Council Directive 89/106/EEC (Text with EEA relevance) '},
#   'date': {'type': 'typed-literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#date',
#    'value': '2014-06-16'},
#   'class': {'type': 'uri',
#    'value': 'http://publications.europa.eu/ontology/cdm#measure_national_implementing'},
#   'className': {'type': 'literal', 'value': 'measure_national_implementing'},
#   'authorName': {'type': 'literal',
#    'xml:lang': 'en',
#    'value': 'Provisional data'}},
#  {'item': {'type': 'uri',
#    'value': 'http://publications.europa.eu/resource/cellar/3d4572e0-3dcd-432d-85ad-ad918607176b.0020.02/DOC_1'},
#   'expr_title': {'type': 'typed-literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#    'value': 'Regulation (EU) No 305/2011 of the European Parliament and of the Council of 9 March 2011 laying down harmonised conditions for the marketing of construction products and repealing Council Directive 89/106/EEC (Text with EEA relevance) '},
#   'date': {'type': 'typed-literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#date',
#    'value': '2014-06-16'},
#   'class': {'type': 'uri',
#    'value': 'http://publications.europa.eu/ontology/cdm#official-journal'},
#   'className': {'type': 'literal', 'value': 'official-journal'},
#   'authorName': {'type': 'literal',
#    'xml:lang': 'en',
#    'value': 'Provisional data'}},
#  {'item': {'type': 'uri',
#    'value': 'http://publications.europa.eu/resource/cellar/3d4572e0-3dcd-432d-85ad-ad918607176b.0020.02/DOC_1'},
#   'expr_title': {'type': 'typed-literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#    'value': 'Regulation (EU) No 305/2011 of the European Parliament and of the Council of 9 March 2011 laying down harmonised conditions for the marketing of construction products and repealing Council Directive 89/106/EEC (Text with EEA relevance) '},
#   'date': {'type': 'typed-literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#date',
#    'value': '2014-06-16'},
#   'class': {'type': 'uri',
#    'value': 'http://publications.europa.eu/ontology/cdm#oj_c'},
#   'className': {'type': 'literal', 'value': 'oj_c'},
#   'authorName': {'type': 'literal',
#    'xml:lang': 'en',
#    'value': 'Provisional data'}},
#  {'item': {'type': 'uri',
#    'value': 'http://publications.europa.eu/resource/cellar/3d4572e0-3dcd-432d-85ad-ad918607176b.0020.02/DOC_1'},
#   'expr_title': {'type': 'typed-literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#    'value': 'Regulation (EU) No 305/2011 of the European Parliament and of the Council of 9 March 2011 laying down harmonised conditions for the marketing of construction products and repealing Council Directive 89/106/EEC (Text with EEA relevance) '},
#   'date': {'type': 'typed-literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#date',
#    'value': '2014-06-16'},
#   'class': {'type': 'uri',
#    'value': 'http://publications.europa.eu/ontology/cdm#question_parliamentary'},
#   'className': {'type': 'literal', 'value': 'question_parliamentary'},
#   'authorName': {'type': 'literal',
#    'xml:lang': 'en',
#    'value': 'Provisional data'}},
#  {'item': {'type': 'uri',
#    'value': 'http://publications.europa.eu/resource/cellar/3d4572e0-3dcd-432d-85ad-ad918607176b.0020.02/DOC_1'},
#   'expr_title': {'type': 'typed-literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#    'value': 'Regulation (EU) No 305/2011 of the European Parliament and of the Council of 9 March 2011 laying down harmonised conditions for the marketing of construction products and repealing Council Directive 89/106/EEC (Text with EEA relevance) '},
#   'date': {'type': 'typed-literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#date',
#    'value': '2014-06-16'},
#   'class': {'type': 'uri',
#    'value': 'http://publications.europa.eu/ontology/cdm#treaty'},
#   'className': {'type': 'literal', 'value': 'treaty'},
#   'authorName': {'type': 'literal',
#    'xml:lang': 'en',
#    'value': 'Provisional data'}},
#  {'item': {'type': 'uri',
#    'value': 'http://publications.europa.eu/resource/cellar/3d4572e0-3dcd-432d-85ad-ad918607176b.0020.02/DOC_1'},
#   'expr_title': {'type': 'typed-literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#    'value': 'Regulation (EU) No 305/2011 of the European Parliament and of the Council of 9 March 2011 laying down harmonised conditions for the marketing of construction products and repealing Council Directive 89/106/EEC (Text with EEA relevance) '},
#   'date': {'type': 'typed-literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#date',
#    'value': '2014-06-16'},
#   'class': {'type': 'uri',
#    'value': 'http://publications.europa.eu/ontology/cdm#document-budgetary'},
#   'className': {'type': 'literal', 'value': 'document-budgetary'},
#   'authorName': {'type': 'literal',
#    'xml:lang': 'en',
#    'value': 'Provisional data'}},
#  {'item': {'type': 'uri',
#    'value': 'http://publications.europa.eu/resource/cellar/3d4572e0-3dcd-432d-85ad-ad918607176b.0020.02/DOC_1'},
#   'expr_title': {'type': 'typed-literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#    'value': 'Regulation (EU) No 305/2011 of the European Parliament and of the Council of 9 March 2011 laying down harmonised conditions for the marketing of construction products and repealing Council Directive 89/106/EEC (Text with EEA relevance) '},
#   'date': {'type': 'typed-literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#date',
#    'value': '2014-06-16'},
#   'class': {'type': 'uri',
#    'value': 'http://publications.europa.eu/ontology/cdm#document-ec'},
#   'className': {'type': 'literal', 'value': 'document-ec'},
#   'authorName': {'type': 'literal',
#    'xml:lang': 'en',
#    'value': 'Provisional data'}}]

# %%
os.makedirs("data/api_download", exist_ok=True)
# Call to the  API to download the digital file
unique_items = set([r["item"]["value"] for r in results["results"]["bindings"]])
for doc_url in unique_items:
    item = '.'.join(doc_url.split("/")[-2:])
    file_name = "data/api_download/" + item + ".xhtml"
    try:
        response = requests.get(doc_url)
    except Exception as e:
        print(f"Error downloading {doc_url}: {e}")
        continue
    
    with open(file_name, 'w', encoding='utf-8') as file:
        file.write(response.text)
        print(f"Downloaded: {file_name}")
# Out:
# Downloaded: data/api_download/ea3bdcba-e537-4749-b2dc-4457734dbfcf.0002.02.DOC_1.xhtml
# Downloaded: data/api_download/3d4572e0-3dcd-432d-85ad-ad918607176b.0020.02.DOC_1.xhtml

# %% [markdown]
# # RSS Feed

# %%
import os
import requests
import feedparser
import json
import pandas as pd
from dotenv import load_dotenv
from pandas import json_normalize
from datetime import datetime, timezone
load_dotenv(override=True)
# Out:
# True

# %%
pd.set_option('display.max_rows', 50)

# %%
# Replace this with your EUR-Lex RSS feed URL
rss_url = "https://eur-lex.europa.eu/EN/display-feed.rss?myRssId=zqe48ppy80IwdPmk3HJVPsD4fM281XNaoMTLQ6ifL58%3D"

# Parse the RSS feed
feed = feedparser.parse(rss_url)

# Loop through the latest entries
for entry in feed.entries:
    title = entry.title
    link = entry.link
    published = entry.published  # e.g., "Fri, 29 Aug 2025 12:00:00 GMT"

    print(f"Title: {title}")
    print(f"Link: {link}")
    print(f"Published: {published}")
    print("-" * 50)
# Out:
# Title: CELEX:32025D1734: Decision (EU) 2025/1734 of the European Central Bank of 31 July 2025 on safeguards in relation to access by central counterparties to Eurosystem overnight credit in TARGET (ECB/2025/29)
# Link: https://eur-lex.europa.eu/./legal-content/AUTO/?uri=CELEX:32025D1734
# Published: Wed, 13 Aug 2025 00:00:00 +0200
# --------------------------------------------------
# Title: CELEX:32025R0791: Commission Delegated Regulation (EU) 2025/791 of 23 April 2025 supplementing Directive 2013/36/EU of the European Parliament and of the Council with regard to regulatory technical standards specifying the general conditions for the functioning of supervisory colleges, and repealing Commission Delegated Regulation (EU) 2016/98
# Link: https://eur-lex.europa.eu/./legal-content/AUTO/?uri=CELEX:32025R0791
# Published: Fri, 08 Aug 2025 00:00:00 +0200
# --------------------------------------------------
# Title: CELEX:32025R0790: Commission Implementing Regulation (EU) 2025/790 of 23 April 2025 laying down implementing technical standards for the application of Directive 2013/36/EU of the European Parliament and of the Council with regard to the operational functioning of colleges of supervisors
# Link: https://eur-lex.europa.eu/./legal-content/AUTO/?uri=CELEX:32025R0790
# Published: Fri, 08 Aug 2025 00:00:00 +0200
# --------------------------------------------------
# Title: CELEX:32025R0789: Commission Delegated Regulation (EU) 2025/789 of 23 April 2025 supplementing Regulation (EU) No 575/2013 of the European Parliament and of the Council with regard to regulatory technical standards specifying the conditions and indicators that the EBA is to use to determine whether extraordinary circumstances in the sense of Article 325az(5) and Article 325bf(6) of that Regulation have occurred
# Link: https://eur-lex.europa.eu/./legal-content/AUTO/?uri=CELEX:32025R

# Link: https://eur-lex.europa.eu/./legal-content/AUTO/?uri=CELEX:32024R2987
# Published: Wed, 04 Dec 2024 00:00:00 +0100
# --------------------------------------------------
# Title: CELEX:32024L2994: Directive (EU) 2024/2994 of the European Parliament and of the Council of 27 November 2024 amending Directives 2009/65/EC, 2013/36/EU and (EU) 2019/2034 as regards the treatment of concentration risk arising from exposures towards central counterparties and of counterparty risk in centrally cleared derivative transactions (Text with EEA relevance)
# Link: https://eur-lex.europa.eu/./legal-content/AUTO/?uri=CELEX:32024L2994
# Published: Wed, 04 Dec 2024 00:00:00 +0100
# --------------------------------------------------
# Title: CELEX:32024R2956: Commission Implementing Regulation (EU) 2024/2956 of 29 November 2024 laying down implementing technical standards for the application of Regulation (EU) 2022/2554 of the European Parliament and of the Council with regard to standard templates for the register of information
# Link: https://eur-lex.europa.eu/./legal-content/AUTO/?uri=CELEX:32024R2956
# Published: Mon, 02 Dec 2024 00:00:00 +0100
# --------------------------------------------------
# Title: CELEX:32024R2915: Commission Implementing Regulation (EU) 2024/2915 of 25 November 2024 specifying technical items of data sets of the sample survey in the income and living conditions domain on over-indebtedness, consumption and wealth pursuant to Regulation (EU) 2019/1700 of the European Parliament and of the Council, and amending Commission Implementing Regulation (EU) 2021/2052
# Link: https://eur-lex.europa.eu/./legal-content/AUTO/?uri=CELEX:32024R2915
# Published: Tue, 26 Nov 2024 00:00:00 +0100
# --------------------------------------------------
# Title: CELEX:32024D2901: Commission Implementing Decision (EU) 2024/2901 of 14 November 2024 amending Implementing Decision (EU) 2023/1602 on the primary dealer network and the definition of eligibility criteria for lead and co-lead mandates for syndicated transactions for the purposes of the borrowing activities by the Commission on behalf of the Union and of the European Atomic Energy Community
# Link: https://eur-lex.europa.eu/./legal-content/AUTO/?uri=CELEX:32024D2901
# Published: Mon, 18 Nov 2024 00:00:00 +0100
# --------------------------------------------------
# Title: CELEX:32024O2616R(01): Corrigendum to Guideline (EU) 2024/2616 of the European Central Bank of 30 July 2024 amending Guideline (EU) 2022/912 on a new-generation Trans-European Automated Real-time Gross Settlement Express Transfer system (TARGET) (ECB/2022/8) (ECB/2024/20) (OJ L, 2024/90716, 4.10.2024)
# Link: https://eur-lex.europa.eu/./legal-content/AUTO/?uri=CELEX:32024O2616R(01)
# Published: Fri, 15 Nov 2024 00:00:00 +0100
# --------------------------------------------------
# Title: CELEX:32024L2811: Directive (EU) 2024/2811 of the European Parliament and of the Council of 23 October 2024 amending Directive 2014/65/EU to make public capital markets in the Union more attractive for companies and to facilitate access to capital for small and medium-sized enterprises and repealing Directive 2001/34/EC (Text with EEA relevance)
# Link: https://eur-lex.europa.eu/./legal-content/AUTO/?uri=CELEX:32024L2811
# Published: Thu, 14 Nov 2024 00:00:00 +0100
# --------------------------------------------------
# Title: CELEX:32024Y06967: Recommendation of the European Systemic Risk Board of 27 September 2024 amending Recommendation ESRB/2015/2 on the assessment of cross-border effects of and voluntary reciprocity for macroprudential policy measures (ESRB/2024/5)
# Link: https://eur-lex.europa.eu/./legal-content/AUTO/?uri=CELEX:32024Y06967
# Published: Thu, 14 Nov 2024 00:00:00 +0100
# --------------------------------------------------
# Title: CELEX:32024R2759R(01): Corrigendum to Commission Delegated Regulation (EU) 2024/2759 of 19 July 2024 supplementing Regulation (EU) 2015/760 of the European Parliament and of the Council with regard to regulatory technical standards specifying when derivatives will be used solely for hedging the risks inherent to other investments of the European long-term investment fund (ELTIF), the requirements for an ELTIF’s redemption policy and liquidity management tools, the circumstances for the matching of transfer requests of units or shares of the ELTIF, certain criteria for the disposal of ELTIF assets, and certain elements of the costs disclosure (OJ L, 2024/2759, 25.10.2024)
# Link: https://eur-lex.europa.eu/./legal-content/AUTO/?uri=CELEX:32024R2759R(01)
# Published: Wed, 06 Nov 2024 00:00:00 +0100
# --------------------------------------------------
# Title: CELEX:32024D2830: Decision (EU) 2024/2830 of the European Central Bank of 29 October 2024 amending Decision (EU) 2022/911 concerning the terms and conditions of TARGET-ECB (ECB/2022/22) (ECB/2024/30)
# Link: https://eur-lex.europa.eu/./legal-content/AUTO/?uri=CELEX:32024D2830
# Published: Tue, 05 Nov 2024 00:00:00 +0100
# --------------------------------------------------
# Title: CELEX:32024O2798: Guideline (EU) 2024/2798 of the European Central Bank of 10 October 2024 amending Guideline (EU) 2021/831 on statistical information to be reported on financial intermediaries other than monetary financial institutions (ECB/2021/12) (ECB/2024/27)
# Link: https://eur-lex.europa.eu/./legal-content/AUTO/?uri=CELEX:32024O2798
# Published: Mon, 04 Nov 2024 00:00:00 +0100
# --------------------------------------------------
# Title: CELEX:32

# Link: https://eur-lex.europa.eu/./legal-content/AUTO/?uri=CELEX:32024R1624
# Published: Wed, 19 Jun 2024 00:00:00 +0200
# --------------------------------------------------
# Title: CELEX:32024R1623: Regulation (EU) 2024/1623 of the European Parliament and of the Council of 31 May 2024 amending Regulation (EU) No 575/2013 as regards requirements for credit risk, credit valuation adjustment risk, operational risk, market risk and the output floor (Text with EEA relevance)
# Link: https://eur-lex.europa.eu/./legal-content/AUTO/?uri=CELEX:32024R1623
# Published: Wed, 19 Jun 2024 00:00:00 +0200
# --------------------------------------------------
# Title: CELEX:32024R1620: Regulation (EU) 2024/1620 of the European Parliament and of the Council of 31 May 2024 establishing the Authority for Anti-Money Laundering and Countering the Financing of Terrorism and amending Regulations (EU) No 1093/2010, (EU) No 1094/2010 and (EU) No 1095/2010 (Text with EEA relevance)
# Link: https://eur-lex.europa.eu/./legal-content/AUTO/?uri=CELEX:32024R1620
# Published: Wed, 19 Jun 2024 00:00:00 +0200
# --------------------------------------------------
# Title: CELEX:32024L1640: Directive (EU) 2024/1640 of the European Parliament and of the Council of 31 May 2024 on the mechanisms to be put in place by Member States for the prevention of the use of the financial system for the purposes of money laundering or terrorist financing, amending Directive(EU) 2019/1937, and amending and repealing Directive (EU) 2015/849 (Text with EEA relevance)
# Link: https://eur-lex.europa.eu/./legal-content/AUTO/?uri=CELEX:32024L1640
# Published: Wed, 19 Jun 2024 00:00:00 +0200
# --------------------------------------------------
# Title: CELEX:32024R1705: Commission Delegated Regulation (EU) 2024/1705 of 11 March 2024 amending Delegated Regulation (EU) 2022/805 as regards harmonisation of certain aspects of fees charged by the European Securities and Markets Authority to certain benchmark administrators
# Link: https://eur-lex.europa.eu/./legal-content/AUTO/?uri=CELEX:32024R1705
# Published: Tue, 18 Jun 2024 00:00:00 +0200
# --------------------------------------------------
# Title: CELEX:32024R1700: Commission Delegated Regulation (EU) 2024/1700 of 5 March 2024 supplementing Regulation (EU) 2017/2402 of the European Parliament and of the Council with regard to regulatory technical standards specifying, for simple, transparent and standardised non-ABCP traditional securitisation, and for simple, transparent and standardised on-balance-sheet securitisation, the content, methodologies and presentation of information related to the principal adverse impacts of the assets financed by the underlying exposures on sustainability factors
# Link: https://eur-lex.europa.eu/./legal-content/AUTO/?uri=CELEX:32024R1700
# Published: Tue, 18 Jun 2024 00:00:00 +0200
# --------------------------------------------------
# Title: CELEX:32024R1706: Commission Delegated Regulation (EU) 2024/1706 of 11 March 2024 amending Delegated Regulation (EU) No 272/2012 as regards harmonisation of certain aspects of fees charged by the European Securities and Markets Authority to credit rating agencies
# Link: https://eur-lex.europa.eu/./legal-content/AUTO/?uri=CELEX:32024R1706
# Published: Tue, 18 Jun 2024 00:00:00 +0200
# --------------------------------------------------
# Title: CELEX:32024R1704: Commission Delegated Regulation (EU) 2024/1704 of 11 March 2024 amending Delegated Regulation (EU) 2019/360 as regards harmonisation of certain aspects of fees charged by the European Securities and Markets Authority to trade repositories
# Link: https://eur-lex.europa.eu/./legal-content/AUTO/?uri=CELEX:32024R1704
# Published: Tue, 18 Jun 2024 00:00:00 +0200
# --------------------------------------------------

# %%
feed.entries[0]
# Out:
# {'title': 'CELEX:32025D1734: Decision (EU) 2025/1734 of the European Central Bank of 31\xa0July 2025 on safeguards in relation to access by central counterparties to Eurosystem overnight credit in TARGET (ECB/2025/29)',
#  'title_detail': {'type': 'text/plain',
#   'language': 'en',
#   'base': 'https://eur-lex.europa.eu/EN/display-feed.rss?myRssId=zqe48ppy80IwdPmk3HJVPsD4fM281XNaoMTLQ6ifL58%3D',
#   'value': 'CELEX:32025D1734: Decision (EU) 2025/1734 of the European Central Bank of 31\xa0July 2025 on safeguards in relation to access by central counterparties to Eurosystem overnight credit in TARGET (ECB/2025/29)'},
#  'summary': '',
#  'summary_detail': {'type': 'text/html',
#   'language': 'en',
#   'base': 'https://eur-lex.europa.eu/EN/display-feed.rss?myRssId=zqe48ppy80IwdPmk3HJVPsD4fM281XNaoMTLQ6ifL58%3D',
#   'value': ''},
#  'links': [{'rel': 'alternate',
#    'type': 'text/html',
#    'href': 'https://eur-lex.europa.eu/./legal-content/AUTO/?uri=CELEX:32025D1734'}],
#  'link': 'https://eur-lex.europa.eu/./legal-content/AUTO/?uri=CELEX:32025D1734',
#  'id': 'https://eur-lex.europa.eu/./legal-content/AUTO/?uri=CELLAR:bf08867f-77dd-11f0-9af8-01aa75ed71a1',
#  'guidislink': False,
#  'tags': [{'term': '3', 'scheme': None, 'label': None}],
#  'published': 'Wed, 13 Aug 2025 00:00:00 +0200',
#  'published_parsed': time.struct_time(tm_year=2025, tm_mon=8, tm_mday=12, tm_hour=22, tm_min=0, tm_sec=0, tm_wday=1, tm_yday=224, tm_isdst=0),
#  'authors': [{'name': 'European Central Bank'}],
#  'author': 'European Central Bank',
#  'author_detail': {'name': 'European Central Bank'}}

# %%
new_feed_folder = os.path.join(os.getenv("RAW_DATA_PATH"), "eu/eurlex-feed", datetime.now().strftime("%Y%m%d"))
os.makedirs(new_feed_folder, exist_ok=True)
for entry in feed.entries:
    url = entry.link
    response = requests.get(url)
    celex = entry.title.split(":")[1].strip()
    filename = os.path.join(new_feed_folder, celex + ".html")  # sanitize filename

    with open(filename, "w", encoding="utf-8") as f:
        f.write(response.text)

meta_filename = os.path.join(new_feed_folder, "metadata.json")
with open(meta_filename, "w", encoding="utf-8") as f:
    json.dump(feed.entries, f, indent=4)

# %%
df = json_normalize(
    feed.entries,
    sep='_',  # use underscore to flatten nested dicts
    record_path=None,
    meta=None,
    errors='ignore'
)
df['published_dt'] = pd.to_datetime(df['published'], format = '%a, %d %b %Y %H:%M:%S %z', utc=True)
df = df.sort_values(by='published_dt', ascending=False).reset_index(drop=True)
# df = df[df['published_dt'] > datetime(2025, 1, 1, tzinfo=timezone.utc)]

# %%
tp_ls = [r['links'] for r in feed.entries]
tp_ls[0]
# Out:
# [{'rel': 'alternate',
#   'type': 'text/html',
#   'href': 'https://eur-lex.europa.eu/./legal-content/AUTO/?uri=CELEX:32025D1734'}]

# %%
import psycopg2
import os

conn = psycopg2.connect(
    host=os.getenv("DB_HOST"),
    port=os.getenv("DB_PORT"),
    user=os.getenv("DB_USER"),
    password=os.getenv("DB_PASSWORD"),
    dbname=os.getenv("DB_NAME")
)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[18], line 4
#       1 import psycopg2
#       2 import os
# ----> 4 conn = psycopg2.connect(
#       5     host=os.getenv("DB_HOST"),
#       6     port=os.getenv("DB_PORT"),
#       7     user=os.getenv("DB_USER"),
#       8     password=os.getenv("DB_PASSWORD"),
#       9     dbname=os.getenv("DB_NAME")
#      10 )
#
# File ~/anaconda3/envs/regpy10/lib/python3.10/site-packages/psycopg2/__init__.py:122, in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     119     kwasync['async_'] = kwargs.pop('async_')
#     121 dsn = _ext.make_dsn(dsn, **kwargs)
# --> 122 conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     123 if cursor_factory is not None:
#     124     conn.cursor_factory = cursor_factory
#
# OperationalError: connection to server at "reg-guru.c3my688ou3oy.ap-southeast-1.rds.amazonaws.com" (47.130.90.234), port 5432 failed: Operation timed out
# 	Is the server running on that host and accepting TCP/IP connections?

# %%
cur = conn.cursor()
for _, row in df.iterrows():
    cur.execute("""
        INSERT INTO legal_acts (celex, title, link, published_dt, author, summary)
        VALUES (%s, %s, %s, %s, %s, %s)
    """, (row['celex'], row['title'], row['link_href'], row['published_dt'], row['author_name'], row['summary']))

conn.commit()
cur.close()
conn.close()
